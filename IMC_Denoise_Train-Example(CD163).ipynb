# %% [markdown]
# # IMC-Denoise: a content aware denoising pipeline to enhance imaging mass cytometry

# %%
import tensorflow as tf
print("GPUs detected:", tf.config.list_physical_devices('GPU'))
# Out:
# GPUs detected: []

# %% [markdown]
# Here we will show an example for denoising the images with marker CD14 from our own human bone marrow IMC dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
from IMC_Denoise.DeepSNiF_utils.DeepSNiF_DataGenerator import DeepSNiF_DataGenerator, load_training_patches
from IMC_Denoise.IMC_Denoise_main.DeepSNiF import DeepSNiF
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Training data preparation
# Next, we use our raw images to build a training set.
# Note:
# 1. The channel name must be consistant with the corresponding channel name in the image file names. For example, in our dataset, CD14 is conjucted with 144Nd. If the images with marker CD14 need to be denoised, the channel name will be set as its isotope name "144Nd".
# 2. Raw_directory is the folder of all the raw images used for generating training set. Its subfolders are the imagesets of different tissues. The subfolders contains the images from all the channels of the same tissue.
# <b><br>Data_structure example:
# <b><br>|---Raw_image_directory
# <br>|---|---Tissue1
# <br>|---|---|---Channel1_img.tiff
# <br>|---|---|---Channel2_img.tiff
# <br>             ...
# <br>|---|---|---Channel_n_img.tiff
# <br>|---|---Tissue2
# <br>|---|---|---Channel1_img.tiff
# <br>|---|---|---Channel2_img.tiff
# <br>             ...
# <br>|---|---|---Channel_n_img.tiff
# <br>             ...
# <br>|---|---Tissue_m
# <br>|---|---|---Channel1_img.tiff
# <br>|---|---|---Channel2_img.tiff
# <br>             ...
# <br>|---|---|---Channel_n_img.tiff
# </b>
# 3. Save_directory is the folder used for saving generated training data. If None, it will be saved in the default folder. For CD14, the saved training set is "training_set_144Nd.npz".
# 4. n_neighbour and n_lambda are the parameters from DIMR algorithm for hot pixel removal in the training set generation process. 4 and 5 are their defaults. If the defaults are changed, the corresponding parameter should be declared in DeepSNiF_DataGenerator(). Otherwise, they can be omitted.
# 5. The DeepSNiF_DataGenerator class search all the CD14 images in raw image directory, split them into multiple 64x64 patches, and then augment the generated data. Note the very sparse patches are removed in this process.
# 6. Here we will save the generated training set and later reload it.

# %%
# Release memory
if 'generated_patches' in globals():
    del generated_patches
    
channel_name = "147Sm"
Raw_directory = "H:\Verona 2024\Denoising_final\Verona Dataset" # change this directory to your Raw_image_directory.
Save_directory = None # If None, it will be saved in the default folder.

n_neighbours = 4 # Larger n enables removing more consecutive hot pixels. 
n_iter = 3 # Iteration number for DIMR

DataGenerator = DeepSNiF_DataGenerator(channel_name = channel_name, n_neighbours = n_neighbours, n_iter = n_iter)
generated_patches = DataGenerator.generate_patches_from_directory(load_directory = Raw_directory)
if DataGenerator.save_patches(generated_patches, save_directory = Save_directory):
    print('Data generated successfully!')
# Out:
# H:\Environments\denoising\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# H:\Environments\denoising\lib\site-packages\numpy\core\_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# Data generated successfully!

# %% [markdown]
# ### Show several generated patches of the training set: Anscombe transformed.

# %%
# show several generated patches of the training set, Anscombe transformed.
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig = plt.figure(figsize=(10, 10))

ax1 = fig.add_subplot(221)
im1 = ax1.imshow(generated_patches[5,:,:], cmap = 'magma')
divider = make_axes_locatable(ax1)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im1, cax=cax, orientation='vertical')

ax2 = fig.add_subplot(222)
im2 = ax2.imshow(generated_patches[100,:,:], cmap = 'magma')
divider = make_axes_locatable(ax2)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im2, cax=cax, orientation='vertical')

ax3 = fig.add_subplot(223)
im3 = ax3.imshow(generated_patches[1001,:,:], cmap = 'magma')
divider = make_axes_locatable(ax3)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im3, cax=cax, orientation='vertical')

ax4 = fig.add_subplot(224)
im4 = ax4.imshow(generated_patches[-1,:,:], cmap = 'magma')
divider = make_axes_locatable(ax4)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im4, cax=cax, orientation='vertical')

# %% [markdown]
# ### Load the generated training data from directory

# %%
saved_training_set = 'training_set_147Sm.npz'
train_data = load_training_patches(filename = saved_training_set, save_directory = Save_directory)
print('The shape of the loaded training set is ' + str(train_data.shape))
# Out:
# The shape of the loaded training set is (1760, 64, 64)

# %% [markdown]
# ### DeepSNiF configuration and training
# Define parameters for DeepSNiF training. If is_load_weights is True, the pre-trained model and pre-calculated range of the marker channel will be loaded. The range value is used for normalization in prediction.

# %%
train_epoches = 200 # training epoches, which should be about 200 for a good training result. The default is 200.
train_initial_lr = 1e-3 # inital learning rate. The default is 1e-3.
train_batch_size = 128 # training batch size. For a GPU with smaller memory, it can be tuned smaller. The default is 128.
pixel_mask_percent = 0.2 # percentage of the masked pixels in each patch. The default is 0.2.
val_set_percent = 0.15 # percentage of validation set. The default is 0.15.
loss_function = "I_divergence" # loss function used. The default is "I_divergence".
weights_name = "weights_147Sm-CD163.keras" # trained network weights name. If None, the weights will not be saved.
loss_name = None # training and validation losses name, either .mat or .npz format. If not defined, the losses will not be saved.
weights_save_directory = None # location where 'weights_name' and 'loss_name' saved.
# If the value is None, the files will be saved in a sub-directory named "trained_weights" of the current file folder.
is_load_weights = False # Use the trained model directly. Will not read from any saved ones.
lambda_HF = 3e-6 # HF regularization parameter.
deepsnif = DeepSNiF(train_epoches = train_epoches, 
                  train_learning_rate = train_initial_lr,
                  train_batch_size = train_batch_size,
                  mask_perc_pix = pixel_mask_percent,
                  val_perc = val_set_percent,
                  loss_func = loss_function,
                  weights_name = weights_name,
                  loss_name = loss_name,
                  weights_dir = weights_save_directory, 
                  is_load_weights = is_load_weights,
                  lambda_HF = lambda_HF)

# %% [markdown]
# ### Start training
# If errors happen, check if the GPUs are being used by other sessions.

# %%
train_loss, val_loss = deepsnif.train(train_data)
# Out:
# Each training patch with shape of (64, 64) will mask 8 pixels.
# Epoch 1/200
# 12/12 [==============================] - 7s 623ms/step - loss: 0.5602 - val_loss: 0.6117
#
# Epoch 00001: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 2/200
# 12/12 [==============================] - 7s 582ms/step - loss: 0.5055 - val_loss: 0.5302
#
# Epoch 00002: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 3/200
# 12/12 [==============================] - 7s 584ms/step - loss: 0.4616 - val_loss: 0.5016
#
# Epoch 00003: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 4/200
# 12/12 [==============================] - 7s 575ms/step - loss: 0.4194 - val_loss: 0.5079
#
# Epoch 00004: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 5/200
# 12/12 [==============================] - 7s 584ms/step - loss: 0.3790 - val_loss: 0.4581
#
# Epoch 00005: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 6/200
# 12/12 [==============================] - 7s 594ms/step - loss: 0.3403 - val_loss: 0.4492
#
# Epoch 00006: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 7/200
# 12/12 [==============================] - 7s 587ms/step - loss: 0.3041 - val_loss: 0.4415
#
# Epoch 00007: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 8/200
# 12/12 [==============================] - 7s 583ms/step - loss: 0.2723 - val_loss: 0.3704
#
# Epoch 00008: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 9/200
# 12/12 [==============================] - 7s 587ms/step - loss: 0.2417 - val_loss: 0.3754
#
# Epoch 00009: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 10/200
# 12/12 [==============================] - 7s 584ms/step - loss: 0.2150 - val_loss: 0.2918
#
# Epoch 00010: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 11/200
# 12/12 [==============================] - 7s 583ms/step - loss: 0.1903 - val_loss: 0.3177
#
# Epoch 00011: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 12/200
# 12/12 [==============================] - 7s 589ms/step - loss: 0.1696 - val_loss: 0.2882
#
# Epoch 00012: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 13/200
# 12/12 [==============================] - 7s 583ms/step - loss: 0.1510 - val_loss: 0.2734
#
# Epoch 00013: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 14/200
# 12/12 [==============================] - 7s 581ms/step - loss: 0.1340 - val_loss: 0.2466
#
# Epoch 00014: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 15/200
# 12/12 [==============================] - 7s 585ms/step - loss: 0.1186 - val_loss: 0.1809
#
# Epoch 00015: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 16/200
# 12/12 [==============================] - 7s 583ms/step - loss: 0.1064 - val_loss: 0.1884
#
# Epoch 00016: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 17/200
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0957 - val_loss: 0.1447
#
# Epoch 00017: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 18/200
# 12/12 [==============================] - 7s 583ms/step - loss: 0.0867 - val_loss: 0.0925
#
# Epoch 00018: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 19/200
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0777 - val_loss: 0.0884
#
# Epoch 00019: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 20/200
# 12/12 [==============================] - 7s 584ms/step - loss: 0.0706 - val_loss: 0.0959
#
# Epoch 00020: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 21/200
# 12/12 [==============================] - 7s 583ms/step - loss: 0.0643 - val_loss: 0.0834
#
# Epoch 00021: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 22/200
# 12/12 [==============================] - 7s 589ms/step - loss: 0.0590 - val_loss: 0.0956
#
# Epoch 00022: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 23/200
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0545 - val_loss: 0.0731
#
# Epoch 00023: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 24/200
# 12/12 [==============================] - 7s 589ms/step - loss: 0.0494 - val_loss: 0.0548
#
# Epoch 00024: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 25/200
# 12/12 [==============================] - 7s 588ms/step - loss: 0.0462 - val_loss: 0.0461
#
# Epoch 00025: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 26/200
# 12/12 [==============================] - 7s 608ms/step - loss: 0.0428 - val_loss: 0.0585
#
# Epoch 00026: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 27/200
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0402 - val_loss: 0.0486
#
# Epoch 00027: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 28/200
# 12/12 [==============================] - 7s 614ms/step - loss: 0.0372 - val_loss: 0.0482
#
# Epoch 00028: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 29/200
# 12/12 [==============================] - 7s 617ms/step - loss: 0.0346 - val_loss: 0.0316
#
# Epoch 00029: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 30/200
# 12/12 [==============================] - 7s 618ms/step - loss: 0.0329 - val_loss: 0.0333
#
# Epoch 00030: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 31/200
# 12/12 [==============================] - 8s 632ms/step - loss: 0.0311 - val_loss: 0.0352
#
# Epoch 00031: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 32/200
# 12/12 [==============================] - 7s 588ms/step - loss: 0.0294 - val_loss: 0.0277
#
# Epoch 00032: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 33/200
# 12/12 [==============================] - 7s 598ms/step - loss: 0.0280 - val_loss: 0.0278
#
# Epoch 00033: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 34/200
# 12/12 [==============================] - 7s 589ms/step - loss: 0.0267 - val_loss: 0.0260
#
# Epoch 00034: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 35/200
# 12/12 [==============================] - 7s 577ms/step - loss: 0.0258 - val_loss: 0.0265
#
# Epoch 00035: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 36/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0244 - val_loss: 0.0221
#
# Epoch 00036: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 37/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0236 - val_loss: 0.0237
#
# Epoch 00037: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 38/200
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0225 - val_loss: 0.0214
#
# Epoch 00038: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 39/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0214 - val_loss: 0.0224
#
# Epoch 00039: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 40/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0208 - val_loss: 0.0213
#
# Epoch 00040: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 41/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0203 - val_loss: 0.0195
#
# Epoch 00041: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 42/200
# 12/12 [==============================] - 7s 578ms/step - loss: 0.0194 - val_loss: 0.0183
#
# Epoch 00042: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 43/200
# 12/12 [==============================] - 7s 590ms/step - loss: 0.0189 - val_loss: 0.0184
#
# Epoch 00043: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 44/200
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0184 - val_loss: 0.0190
#
# Epoch 00044: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 45/200
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0180 - val_loss: 0.0185
#
# Epoch 00045: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 46/200
# 12/12 [==============================] - 7s 584ms/step - loss: 0.0177 - val_loss: 0.0198
#
# Epoch 00046: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 47/200
# 12/12 [==============================] - 7s 587ms/step - loss: 0.0173 - val_loss: 0.0167
#
# Epoch 00047: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 48/200
# 12/12 [==============================] - 7s 577ms/step - loss: 0.0170 - val_loss: 0.0155
#
# Epoch 00048: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 49/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0166 - val_loss: 0.0149
#
# Epoch 00049: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 50/200
# 12/12 [==============================] - 7s 576ms/step - loss: 0.0162 - val_loss: 0.0205
#
# Epoch 00050: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 51/200
# 12/12 [==============================] - 7s 583ms/step - loss: 0.0158 - val_loss: 0.0151
#
# Epoch 00051: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 52/200
# 12/12 [==============================] - 7s 578ms/step - loss: 0.0156 - val_loss: 0.0144
#
# Epoch 00052: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 53/200
# 12/12 [==============================] - 7s 576ms/step - loss: 0.0152 - val_loss: 0.0140
#
# Epoch 00053: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 54/200
# 12/12 [==============================] - 7s 594ms/step - loss: 0.0154 - val_loss: 0.0141
#
# Epoch 00054: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 55/200
# 12/12 [==============================] - 7s 578ms/step - loss: 0.0148 - val_loss: 0.0159
#
# Epoch 00055: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 56/200
# 12/12 [==============================] - 7s 579ms/step - loss: 0.0147 - val_loss: 0.0147
#
# Epoch 00056: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 57/200
# 12/12 [==============================] - 7s 575ms/step - loss: 0.0145 - val_loss: 0.0133
#
# Epoch 00057: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 58/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0145 - val_loss: 0.0130
#
# Epoch 00058: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 59/200
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0141 - val_loss: 0.0131
#
# Epoch 00059: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 60/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0139 - val_loss: 0.0134
#
# Epoch 00060: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 61/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0139 - val_loss: 0.0129
#
# Epoch 00061: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 62/200
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0137 - val_loss: 0.0135
#
# Epoch 00062: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 63/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0135 - val_loss: 0.0128
#
# Epoch 00063: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 64/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0137 - val_loss: 0.0131
#
# Epoch 00064: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 65/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0135 - val_loss: 0.0124
#
# Epoch 00065: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 66/200
# 12/12 [==============================] - 7s 569ms/step - loss: 0.0132 - val_loss: 0.0121
#
# Epoch 00066: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 67/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0131 - val_loss: 0.0122
#
# Epoch 00067: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 68/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0131 - val_loss: 0.0124
#
# Epoch 00068: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 69/200
# 12/12 [==============================] - 7s 567ms/step - loss: 0.0128 - val_loss: 0.0131
#
# Epoch 00069: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 70/200
# 12/12 [==============================] - 7s 569ms/step - loss: 0.0127 - val_loss: 0.0121
#
# Epoch 00070: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 71/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0129 - val_loss: 0.0123
#
# Epoch 00071: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 72/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0129 - val_loss: 0.0122
#
# Epoch 00072: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 73/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0127 - val_loss: 0.0130
#
# Epoch 00073: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 74/200
# 12/12 [==============================] - 7s 595ms/step - loss: 0.0128 - val_loss: 0.0126
#
# Epoch 00074: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 75/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0127 - val_loss: 0.0116
#
# Epoch 00075: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 76/200
# 12/12 [==============================] - 7s 569ms/step - loss: 0.0128 - val_loss: 0.0115
#
# Epoch 00076: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 77/200
# 12/12 [==============================] - 7s 569ms/step - loss: 0.0122 - val_loss: 0.0115
#
# Epoch 00077: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 78/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0128 - val_loss: 0.0113
#
# Epoch 00078: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 79/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0124 - val_loss: 0.0113
#
# Epoch 00079: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 80/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0126 - val_loss: 0.0113
#
# Epoch 00080: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 81/200
# 12/12 [==============================] - 7s 566ms/step - loss: 0.0121 - val_loss: 0.0114
#
# Epoch 00081: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 82/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0125 - val_loss: 0.0113
#
# Epoch 00082: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 83/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0125 - val_loss: 0.0114
#
# Epoch 00083: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 84/200
# 12/12 [==============================] - 7s 577ms/step - loss: 0.0124 - val_loss: 0.0115
#
# Epoch 00084: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 85/200
# 12/12 [==============================] - 7s 569ms/step - loss: 0.0123 - val_loss: 0.0115
#
# Epoch 00085: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 86/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0123 - val_loss: 0.0113
#
# Epoch 00086: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 87/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0124 - val_loss: 0.0111
#
# Epoch 00087: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 88/200
# 12/12 [==============================] - 7s 575ms/step - loss: 0.0124 - val_loss: 0.0110
#
# Epoch 00088: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 89/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0123 - val_loss: 0.0111
#
# Epoch 00089: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 90/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0122 - val_loss: 0.0111
#
# Epoch 00090: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 91/200
# 12/12 [==============================] - 7s 576ms/step - loss: 0.0123 - val_loss: 0.0113
#
# Epoch 00091: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 92/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0120 - val_loss: 0.0112
#
# Epoch 00092: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 93/200
# 12/12 [==============================] - 7s 569ms/step - loss: 0.0121 - val_loss: 0.0110
#
# Epoch 00093: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 94/200
# 12/12 [==============================] - 7s 569ms/step - loss: 0.0120 - val_loss: 0.0113
#
# Epoch 00094: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 95/200
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0118 - val_loss: 0.0112
#
# Epoch 00095: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 96/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0118 - val_loss: 0.0113
#
# Epoch 00096: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 97/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0122 - val_loss: 0.0113
#
# Epoch 00097: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 98/200
# 12/12 [==============================] - 7s 575ms/step - loss: 0.0121 - val_loss: 0.0117
#
# Epoch 00098: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 99/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0118 - val_loss: 0.0113
#
# Epoch 00099: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 100/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0120 - val_loss: 0.0111
#
# Epoch 00100: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 101/200
# 12/12 [==============================] - 7s 577ms/step - loss: 0.0119 - val_loss: 0.0113
#
# Epoch 00101: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 102/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0118 - val_loss: 0.0112
#
# Epoch 00102: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 103/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0119 - val_loss: 0.0111
#
# Epoch 00103: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 104/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0117 - val_loss: 0.0113
#
# Epoch 00104: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 105/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0121 - val_loss: 0.0111
#
# Epoch 00105: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 106/200
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0123 - val_loss: 0.0110
#
# Epoch 00106: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 107/200
# 12/12 [==============================] - 7s 575ms/step - loss: 0.0117 - val_loss: 0.0111
#
# Epoch 00107: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 108/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0121 - val_loss: 0.0113
#
# Epoch 00108: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
#
# Epoch 00108: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 109/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0119 - val_loss: 0.0112
#
# Epoch 00109: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 110/200
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0116 - val_loss: 0.0111
#
# Epoch 00110: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 111/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0119 - val_loss: 0.0110
#
# Epoch 00111: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 112/200
# 12/12 [==============================] - 7s 575ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00112: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 113/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0119 - val_loss: 0.0110
#
# Epoch 00113: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 114/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0119 - val_loss: 0.0112
#
# Epoch 00114: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 115/200
# 12/12 [==============================] - 7s 575ms/step - loss: 0.0120 - val_loss: 0.0111
#
# Epoch 00115: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 116/200
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0116 - val_loss: 0.0113
#
# Epoch 00116: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 117/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0119 - val_loss: 0.0111
#
# Epoch 00117: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 118/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0117 - val_loss: 0.0113
#
# Epoch 00118: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 119/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0119 - val_loss: 0.0111
#
# Epoch 00119: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 120/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0117 - val_loss: 0.0111
#
# Epoch 00120: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 121/200
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0119 - val_loss: 0.0110
#
# Epoch 00121: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 122/200
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00122: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 123/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00123: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 124/200
# 12/12 [==============================] - 7s 589ms/step - loss: 0.0119 - val_loss: 0.0110
#
# Epoch 00124: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 125/200
# 12/12 [==============================] - 7s 577ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00125: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 126/200
# 12/12 [==============================] - 7s 575ms/step - loss: 0.0118 - val_loss: 0.0111
#
# Epoch 00126: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 127/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0117 - val_loss: 0.0109
#
# Epoch 00127: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 128/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0116 - val_loss: 0.0110
#
# Epoch 00128: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 129/200
# 12/12 [==============================] - 7s 575ms/step - loss: 0.0119 - val_loss: 0.0110
#
# Epoch 00129: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 130/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00130: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 131/200
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00131: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 132/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0119 - val_loss: 0.0110
#
# Epoch 00132: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 133/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00133: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 134/200
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0116 - val_loss: 0.0110
#
# Epoch 00134: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 135/200
# 12/12 [==============================] - 7s 575ms/step - loss: 0.0120 - val_loss: 0.0110
#
# Epoch 00135: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 136/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0119 - val_loss: 0.0110
#
# Epoch 00136: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 137/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0119 - val_loss: 0.0111
#
# Epoch 00137: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 138/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0116 - val_loss: 0.0110
#
# Epoch 00138: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 139/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0115 - val_loss: 0.0110
#
# Epoch 00139: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 140/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0116 - val_loss: 0.0111
#
# Epoch 00140: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 141/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0115 - val_loss: 0.0111
#
# Epoch 00141: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 142/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0118 - val_loss: 0.0111
#
# Epoch 00142: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 143/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0120 - val_loss: 0.0111
#
# Epoch 00143: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 144/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0120 - val_loss: 0.0111
#
# Epoch 00144: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 145/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0121 - val_loss: 0.0111
#
# Epoch 00145: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 146/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0115 - val_loss: 0.0111
#
# Epoch 00146: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 147/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0121 - val_loss: 0.0110
#
# Epoch 00147: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 148/200
# 12/12 [==============================] - 7s 561ms/step - loss: 0.0119 - val_loss: 0.0110
#
# Epoch 00148: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
#
# Epoch 00148: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 149/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0116 - val_loss: 0.0110
#
# Epoch 00149: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 150/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00150: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 151/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00151: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 152/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00152: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 153/200
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00153: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 154/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00154: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 155/200
# 12/12 [==============================] - 7s 567ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00155: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 156/200
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0122 - val_loss: 0.0110
#
# Epoch 00156: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 157/200
# 12/12 [==============================] - 7s 567ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00157: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 158/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00158: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 159/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00159: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 160/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0117 - val_loss: 0.0111
#
# Epoch 00160: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 161/200
# 12/12 [==============================] - 7s 566ms/step - loss: 0.0117 - val_loss: 0.0111
#
# Epoch 00161: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 162/200
# 12/12 [==============================] - 7s 577ms/step - loss: 0.0119 - val_loss: 0.0111
#
# Epoch 00162: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 163/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0117 - val_loss: 0.0111
#
# Epoch 00163: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 164/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0115 - val_loss: 0.0110
#
# Epoch 00164: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 165/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0119 - val_loss: 0.0110
#
# Epoch 00165: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 166/200
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00166: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 167/200
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00167: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 168/200
# 12/12 [==============================] - 7s 569ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00168: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
#
# Epoch 00168: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 169/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00169: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 170/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0122 - val_loss: 0.0109
#
# Epoch 00170: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 171/200
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0116 - val_loss: 0.0110
#
# Epoch 00171: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 172/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00172: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 173/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0116 - val_loss: 0.0110
#
# Epoch 00173: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 174/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0120 - val_loss: 0.0110
#
# Epoch 00174: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 175/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0116 - val_loss: 0.0110
#
# Epoch 00175: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 176/200
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0121 - val_loss: 0.0110
#
# Epoch 00176: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 177/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00177: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 178/200
# 12/12 [==============================] - 7s 577ms/step - loss: 0.0115 - val_loss: 0.0110
#
# Epoch 00178: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 179/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0115 - val_loss: 0.0110
#
# Epoch 00179: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 180/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00180: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 181/200
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0115 - val_loss: 0.0110
#
# Epoch 00181: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 182/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00182: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 183/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0112 - val_loss: 0.0110
#
# Epoch 00183: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 184/200
# 12/12 [==============================] - 7s 580ms/step - loss: 0.0116 - val_loss: 0.0110
#
# Epoch 00184: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 185/200
# 12/12 [==============================] - 7s 565ms/step - loss: 0.0116 - val_loss: 0.0110
#
# Epoch 00185: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 186/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00186: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 187/200
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00187: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 188/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0119 - val_loss: 0.0110
#
# Epoch 00188: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
#
# Epoch 00188: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 189/200
# 12/12 [==============================] - 7s 569ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00189: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 190/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0115 - val_loss: 0.0110
#
# Epoch 00190: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 191/200
# 12/12 [==============================] - 7s 567ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00191: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 192/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00192: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 193/200
# 12/12 [==============================] - 7s 567ms/step - loss: 0.0121 - val_loss: 0.0110
#
# Epoch 00193: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 194/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0116 - val_loss: 0.0110
#
# Epoch 00194: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 195/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00195: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 196/200
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0116 - val_loss: 0.0110
#
# Epoch 00196: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 197/200
# 12/12 [==============================] - 7s 570ms/step - loss: 0.0118 - val_loss: 0.0110
#
# Epoch 00197: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 198/200
# 12/12 [==============================] - 7s 569ms/step - loss: 0.0114 - val_loss: 0.0110
#
# Epoch 00198: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 199/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0117 - val_loss: 0.0110
#
# Epoch 00199: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras
# Epoch 200/200
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0119 - val_loss: 0.0110
#
# Epoch 00200: saving model to H:\Verona 2024\Denoising_final\IMC_Denoise\Jupyter_Notebook_examples\trained_weights\weights_147Sm-CD163.keras

# %% [markdown]
# ### Plot the training and validation losses

# %%
plt.figure(figsize=(8, 5))
plt.plot(np.array(range(len(train_loss))),train_loss, color='red', marker='^', linewidth=2, markersize=8)
plt.plot(np.array(range(len(val_loss))),val_loss, color='blue', marker='o', linestyle='dashed', linewidth=2, markersize=8)
plt.xlabel('Epoches')
plt.ylabel('BCE losses')
plt.legend(['training loss', 'val loss'])
plt.show()
